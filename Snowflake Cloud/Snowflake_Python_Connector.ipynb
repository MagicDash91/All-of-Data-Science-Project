# %% [markdown]
# # Install Required Library

# %%
# !pip install snowflake-connector-python
# !pip install snowflake-sqlalchemy
# !pip install sqlalchemy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Make a Connection into your Snowflake account

# %%
import snowflake.connector
from sqlalchemy import create_engine

# %%
# Snowflake connection parameters
username = 'MAGICDASH91'
password = '*************'
account = 'tk11073.europe-west4.gcp'
warehouse = 'COMPUTE_WH'
database = 'DATABASE'
schema = 'PUBLIC'

# Establishing connection
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema
)

# Creating a cursor object
cur = conn.cursor()

# %%
import pandas as pd

# Executing a modified query
cur.execute("""
    SELECT
        NAME,
        YEAR,
        SELLING_PRICE,
        CASE
            WHEN SELLING_PRICE < 100000 THEN 'CHEAP'
            WHEN SELLING_PRICE >= 100000 AND SELLING_PRICE <= 200000 THEN 'NORMAL'
            ELSE 'EXPENSIVE'
        END AS SELLING_PRICE_LABEL
    FROM
        BIKE_DETAILS
""")

# Fetching results
rows = cur.fetchall()

# Creating a Pandas DataFrame
df = pd.DataFrame(rows, columns=['Name', 'Year', 'Selling_Price', 'Selling_Price_Label'])

# Displaying the DataFrame
df
# Out:
#                                      Name  Year  Selling_Price  \
# 0               Royal Enfield Classic 350  2019         175000
# 1                               Honda Dio  2017          45000
# 2     Royal Enfield Classic Gunmetal Grey  2018         150000
# 3       Yamaha Fazer FI V 2.0 [2016-2018]  2015          65000
# 4                   Yamaha SZ [2013-2014]  2011          20000
# ...                                   ...   ...            ...
# 1056                            Activa 3g  2010          17000
# 1057                     Honda CB twister  2012          16000
# 1058                   Bajaj Discover 125  2013          15000
# 1059                       Honda CB Shine  2009          12000
# 1060                     Bajaj Pulsar 150  2008          10000
#
#      Selling_Price_Label
# 0                 NORMAL
# 1                  CHEAP
# 2                 NORMAL
# 3                  CHEAP
# 4                  CHEAP
# ...                  ...
# ...
